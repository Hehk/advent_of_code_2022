# %%
import torch

def load_file(path):
  with open(path) as f:
    return f.read().strip().split('\n\n')

# %%
load_file('example.txt')
# Out:
# ['Monkey 0:\n  Starting items: 79, 98\n  Operation: new = old * 19\n  Test: divisible by 23\n    If true: throw to monkey 2\n    If false: throw to monkey 3',
#  'Monkey 1:\n  Starting items: 54, 65, 75, 74\n  Operation: new = old + 6\n  Test: divisible by 19\n    If true: throw to monkey 2\n    If false: throw to monkey 0',
#  'Monkey 2:\n  Starting items: 79, 60, 97\n  Operation: new = old * old\n  Test: divisible by 13\n    If true: throw to monkey 1\n    If false: throw to monkey 3',
#  'Monkey 3:\n  Starting items: 74\n  Operation: new = old + 3\n  Test: divisible by 17\n    If true: throw to monkey 0\n    If false: throw to monkey 1']

# %%
def parse_monkey(raw_monkey):
  lines = raw_monkey.split('\n')

  id = lines[0].split(' ')[1]
  id = int(id[:-1])

  items = [float(item) for item in lines[1].split(':')[1].split(',')]

  operation = lines[2].split(':')[1].strip()
  operation = operation.replace('new = old ', '')
  [op, num] = operation.split(' ')
  def operation (x):
    y = x
    if num != 'old': 
      y = float(num)
    if op == '+': return x + y
    elif op == '*': return x * y
  
  test = lines[3:]
  # Right now, all the checks are modulo checks
  test_n = int(test[0].split('by ')[1])
  check_fn = lambda x: x % test_n == 0
  true_target = int(test[1].split('throw to monkey ')[1])
  false_target = int(test[2].split('throw to monkey ')[1])
  test = dict(check=check_fn, true_target=true_target, false_target=false_target)

  return dict(id=id, items=items, operation=operation, test=test, inspections=0, test_n=test_n)

# %%
parse_monkey(load_file('example.txt')[0])
# Out:
# {'id': 0,
#  'items': [7.9, 9.8],
#  'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#  'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#   'true_target': 2,
#   'false_target': 3},
#  'inspections': 0}

# %%
def get_monkeys(file):
  return [parse_monkey(raw_monkey) for raw_monkey in load_file(file)]

# %%
get_monkeys('example.txt')
# Out:
# [{'id': 0,
#   'items': [8.5, 7.7, 7.7],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 6,
#    'false_target': 7},
#   'inspections': 0},
#  {'id': 1,
#   'items': [8.0, 9.9],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 3,
#    'false_target': 5},
#   'inspections': 0},
#  {'id': 2,
#   'items': [7.4, 6.0, 7.4, 6.3, 8.6, 9.2, 8.0],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 0,
#    'false_target': 6},
#   'inspections': 0},
#  {'id': 3,
#   'items': [7.1, 5.8, 9.3, 6.5, 8.0, 6.8, 5.4, 7.1],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 2,
#    'false_target': 4},
#   'inspections': 0},
#  {'id': 4,
#   'items': [9.7, 5.6, 7.9, 6.5, 5.8],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 2,
#    'false_target': 0},
#   'inspections': 0},
#  {'id': 5,
#   'items': [7.7],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 4,
#    'false_target': 3},
#   'inspections': 0},
#  {'id': 6,
#   'items': [9.9, 9.0, 8.4, 5.0],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 7,
#    'false_target': 1},
#   'inspections': 0},
#  {'id': 7,
#   'items': [5.0, 6.6, 6.1, 9.2, 6.4, 7.8],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 5,
#    'false_target': 1},
#   'inspections': 0}]

# %%
import math

def get_monkey_by_id(monkeys, id):
  for monkey in monkeys:
    if monkey['id'] == id:
      return monkey
      
def scale_monkeys(monkeys):
  scale = math.prod([monkey['test_n'] for monkey in monkeys])
  for monkey in monkeys:
    monkey['items'] = [item % scale for item in monkey['items']]
  return monkeys

def run_monkeys(monkeys, loop, log=True):
  for monkey in monkeys:
    if log: print('Monkey ' + str(monkey['id']))
    for item in monkey['items']:
      if log: print(f"  Monkey inspects an item with a worry level of {item}.")
      worry = monkey['operation'](item)
      if log: print(f"    Worry level is set to {worry}.")
      if log: print(f"    Monkey gets bored with item. Worry level is divided by 3 to {worry}.")
      if monkey['test']['check'](worry):
        if log: print(f"    Passed the monkey's check")
        if log: print(f"    Monkey throws item to monkey {monkey['test']['true_target']}.")
        target_monkey = get_monkey_by_id(monkeys, monkey['test']['true_target'])
        target_monkey['items'].append(worry)
      else:
        if log: print(f"    Failed the monkey's check")
        if log: print(f"    Monkey throws item to monkey {monkey['test']['false_target']}.")
        target_monkey = get_monkey_by_id(monkeys, monkey['test']['false_target'])
        target_monkey['items'].append(worry)
    monkey['inspections'] += len(monkey['items'])
    monkey['items'] = []
  if log: print(monkeys)
  monkeys = scale_monkeys(monkeys)
  return monkeys

# %%
def run_monkeys_n_times(monkeys, n):
  for i in range(n):
    monkeys = run_monkeys(monkeys, loop=i, log=False)
    iteration = i + 1
    if iteration % 1_000 == 0 or iteration == 20 or iteration == 1:
      print('Iteration:', i + 1)
      for monkey in monkeys:
        print(f"Monkey {monkey['id']} has inspected {monkey['inspections']} items.")
      print('')
  return monkeys

# %%
run_monkeys_n_times(get_monkeys('example.txt'), 10_000)
# Out:
# Iteration: 1
# Monkey 0 has inspected 2 items.
# Monkey 1 has inspected 4 items.
# Monkey 2 has inspected 3 items.
# Monkey 3 has inspected 6 items.
#
# Iteration: 20
# Monkey 0 has inspected 99 items.
# Monkey 1 has inspected 97 items.
# Monkey 2 has inspected 8 items.
# Monkey 3 has inspected 103 items.
#
# Iteration: 1000
# Monkey 0 has inspected 5204 items.
# Monkey 1 has inspected 4792 items.
# Monkey 2 has inspected 199 items.
# Monkey 3 has inspected 5192 items.
#
# Iteration: 2000
# Monkey 0 has inspected 10419 items.
# Monkey 1 has inspected 9577 items.
# Monkey 2 has inspected 392 items.
# Monkey 3 has inspected 10391 items.
#
# Iteration: 3000
# Monkey 0 has inspected 15638 items.
# Monkey 1 has inspected 14358 items.
# Monkey 2 has inspected 587 items.
# Monkey 3 has inspected 15593 items.
#
# Iteration: 4000
# Monkey 0 has inspected 20858 items.
# Monkey 1 has inspected 19138 items.
# Monkey 2 has inspected 780 items.
# Monkey 3 has inspected 20797 items.
#
# Iteration: 5000
# Monkey 0 has inspected 26075 items.
# Monkey 1 has inspected 23921 items.
# Monkey 2 has inspected 974 items.
# Monkey 3 has inspected 26000 items.
#
# Iteration: 6000
# Monkey 0 has inspected 31294 items.
# Monkey 1 has inspected 28702 items.
# Monkey 2 has inspected 1165 items.
# Monkey 3 has inspected 31204 items.
#
# Iteration: 7000
# Monkey 0 has inspected 36508 items.
# Monkey 1 has inspected 33488 items.
# Monkey 2 has inspected 1360 items.
# Monkey 3 has inspected 36400 items.
#
# Iteration: 8000
# Monkey 0 has inspected 41728 items.
# Monkey 1 has inspected 38268 items.
# Monkey 2 has inspected 1553 items.
# Monkey 3 has inspected 41606 items.
#
# Iteration: 9000
# Monkey 0 has inspected 46945 items.
# Monkey 1 has inspected 43051 items.
# Monkey 2 has inspected 1746 items.
# Monkey 3 has inspected 46807 items.
#
# Iteration: 10000
# Monkey 0 has inspected 52166 items.
# Monkey 1 has inspected 47830 items.
# Monkey 2 has inspected 1938 items.
# Monkey 3 has inspected 52013 items.
# [{'id': 0,
#   'items': [63602.0, 56040.0, 11941.0, 10573.0, 61607.0],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 2,
#    'false_target': 3},
#   'inspections': 52166,
#   'test_n': 23},
#  {'id': 1,
#   'items': [90861.0, 86149.0, 27648.0, 21340.0, 76915.0],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 2,
#    'false_target': 0},
#   'inspections': 47830,
#   'test_n': 19},
#  {'id': 2,
#   'items': [],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 1,
#    'false_target': 3},
#   'inspections': 1938,
#   'test_n': 13},
#  {'id': 3,
#   'items': [],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 0,
#    'false_target': 1},
#   'inspections': 52013,
#   'test_n': 17}]

# %%
[monkey['inspections'] for monkey in run_monkeys_n_times(get_monkeys('input.txt'), 10_000)]
# Out:
# Iteration: 1
# Monkey 0 has inspected 3 items.
# Monkey 1 has inspected 2 items.
# Monkey 2 has inspected 7 items.
# Monkey 3 has inspected 9 items.
# Monkey 4 has inspected 14 items.
# Monkey 5 has inspected 2 items.
# Monkey 6 has inspected 11 items.
# Monkey 7 has inspected 10 items.
#
# Iteration: 20
# Monkey 0 has inspected 119 items.
# Monkey 1 has inspected 140 items.
# Monkey 2 has inspected 147 items.
# Monkey 3 has inspected 231 items.
# Monkey 4 has inspected 158 items.
# Monkey 5 has inspected 198 items.
# Monkey 6 has inspected 135 items.
# Monkey 7 has inspected 137 items.
#
# Iteration: 1000
# Monkey 0 has inspected 6002 items.
# Monkey 1 has inspected 5692 items.
# Monkey 2 has inspected 6353 items.
# Monkey 3 has inspected 11668 items.
# Monkey 4 has inspected 6034 items.
# Monkey 5 has inspected 11628 items.
# Monkey 6 has inspected 6010 items.
# Monkey 7 has inspected 6343 items.
#
# Iteration: 2000
# Monkey 0 has inspected 12002 items.
# Monkey 1 has inspected 11361 items.
# Monkey 2 has inspected 12689 items.
# Monkey 3 has inspected 23329 items.
# Monkey 4 has inspected 12038 items.
# Monkey 5 has inspected 23294 items.
# Monkey 6 has inspected 12013 items.
# Monkey 7 has inspected 12680 items.
#
# Iteration: 3000
# Monkey 0 has inspected 17996 items.
# Monkey 1 has inspected 17030 items.
# Monkey 2 has inspected 19029 items.
# Monkey 3 has inspected 34998 items.
# Monkey 4 has inspected 18031 items.
# Monkey 5 has inspected 34961 items.
# Monkey 6 has inspected 18017 items.
# Monkey 7 has inspected 19005 items.
#
# Iteration: 4000
# Monkey 0 has inspected 24002 items.
# Monkey 1 has inspected 22692 items.
# Monkey 2 has inspected 25353 items.
# Monkey 3 has inspected 46668 items.
# Monkey 4 has inspected 24034 items.
# Monkey 5 has inspected 46628 items.
# Monkey 6 has inspected 24010 items.
# Monkey 7 has inspected 25343 items.
#
# Iteration: 5000
# Monkey 0 has inspected 30002 items.
# Monkey 1 has inspected 28361 items.
# Monkey 2 has inspected 31689 items.
# Monkey 3 has inspected 58329 items.
# Monkey 4 has inspected 30038 items.
# Monkey 5 has inspected 58294 items.
# Monkey 6 has inspected 30013 items.
# Monkey 7 has inspected 31680 items.
#
# Iteration: 6000
# Monkey 0 has inspected 35996 items.
# Monkey 1 has inspected 34030 items.
# Monkey 2 has inspected 38029 items.
# Monkey 3 has inspected 69998 items.
# Monkey 4 has inspected 36031 items.
# Monkey 5 has inspected 69961 items.
# Monkey 6 has inspected 36017 items.
# Monkey 7 has inspected 38005 items.
#
# Iteration: 7000
# Monkey 0 has inspected 42002 items.
# Monkey 1 has inspected 39692 items.
# Monkey 2 has inspected 44353 items.
# Monkey 3 has inspected 81668 items.
# Monkey 4 has inspected 42034 items.
# Monkey 5 has inspected 81628 items.
# Monkey 6 has inspected 42010 items.
# Monkey 7 has inspected 44343 items.
#
# Iteration: 8000
# Monkey 0 has inspected 48002 items.
# Monkey 1 has inspected 45361 items.
# Monkey 2 has inspected 50689 items.
# Monkey 3 has inspected 93329 items.
# Monkey 4 has inspected 48038 items.
# Monkey 5 has inspected 93294 items.
# Monkey 6 has inspected 48013 items.
# Monkey 7 has inspected 50680 items.
#
# Iteration: 9000
# Monkey 0 has inspected 53996 items.
# Monkey 1 has inspected 51030 items.
# Monkey 2 has inspected 57029 items.
# Monkey 3 has inspected 104998 items.
# Monkey 4 has inspected 54031 items.
# Monkey 5 has inspected 104961 items.
# Monkey 6 has inspected 54017 items.
# Monkey 7 has inspected 57005 items.
#
# Iteration: 10000
# Monkey 0 has inspected 60002 items.
# Monkey 1 has inspected 56692 items.
# Monkey 2 has inspected 63353 items.
# Monkey 3 has inspected 116668 items.
# Monkey 4 has inspected 60034 items.
# Monkey 5 has inspected 116628 items.
# Monkey 6 has inspected 60010 items.
# Monkey 7 has inspected 63343 items.
# [60002, 56692, 63353, 116668, 60034, 116628, 60010, 63343]

# %%
116668 * 116628
# Out:
# 13606755504

# %%
232 * 236
# Out:
# 54752

# %%
10_000 / 20
# Out:
# 500.0

# %%
run_monkeys(get_monkeys('example.txt'), 0, log=True)
# Out:
# Monkey 0
#   Monkey inspects an item with a worry level of 85.
#     Worry level is set to 595.
#     Monkey gets bored with item. Worry level is divided by 3 to 595.
#     Failed the monkey's check
#     Monkey throws item to monkey 7.
#   Monkey inspects an item with a worry level of 77.
#     Worry level is set to 539.
#     Monkey gets bored with item. Worry level is divided by 3 to 539.
#     Failed the monkey's check
#     Monkey throws item to monkey 7.
#   Monkey inspects an item with a worry level of 77.
#     Worry level is set to 539.
#     Monkey gets bored with item. Worry level is divided by 3 to 539.
#     Failed the monkey's check
#     Monkey throws item to monkey 7.
# Monkey 1
#   Monkey inspects an item with a worry level of 80.
#     Worry level is set to 880.
#     Monkey gets bored with item. Worry level is divided by 3 to 880.
#     Failed the monkey's check
#     Monkey throws item to monkey 5.
#   Monkey inspects an item with a worry level of 99.
#     Worry level is set to 1089.
#     Monkey gets bored with item. Worry level is divided by 3 to 1089.
#     Passed the monkey's check
#     Monkey throws item to monkey 3.
# Monkey 2
#   Monkey inspects an item with a worry level of 74.
#     Worry level is set to 82.
#     Monkey gets bored with item. Worry level is divided by 3 to 82.
#     Failed the monkey's check
#     Monkey throws item to monkey 6.
#   Monkey inspects an item with a worry level of 60.
#     Worry level is set to 68.
#     Monkey gets bored with item. Worry level is divided by 3 to 68.
#     Failed the monkey's check
#     Monkey throws item to monkey 6.
#   Monkey inspects an item with a worry level of 74.
#     Worry level is set to 82.
#     Monkey gets bored with item. Worry level is divided by 3 to 82.
#     Failed the monkey's check
#     Monkey throws item to monkey 6.
#   Monkey inspects an item with a worry level of 63.
#     Worry level is set to 71.
#     Monkey gets bored with item. Worry level is divided by 3 to 71.
#     Failed the monkey's check
#     Monkey throws item to monkey 6.
#   Monkey inspects an item with a worry level of 86.
#     Worry level is set to 94.
#     Monkey gets bored with item. Worry level is divided by 3 to 94.
#     Failed the monkey's check
#     Monkey throws item to monkey 6.
#   Monkey inspects an item with a worry level of 92.
#     Worry level is set to 100.
#     Monkey gets bored with item. Worry level is divided by 3 to 100.
#     Failed the monkey's check
#     Monkey throws item to monkey 6.
#   Monkey inspects an item with a worry level of 80.
#     Worry level is set to 88.
#     Monkey gets bored with item. Worry level is divided by 3 to 88.
#     Failed the monkey's check
#     Monkey throws item to monkey 6.
# Monkey 3
#   Monkey inspects an item with a worry level of 71.
#     Worry level is set to 78.
#     Monkey gets bored with item. Worry level is divided by 3 to 78.
#     Failed the monkey's check
#     Monkey throws item to monkey 4.
#   Monkey inspects an item with a worry level of 58.
#     Worry level is set to 65.
#     Monkey gets bored with item. Worry level is divided by 3 to 65.
#     Failed the monkey's check
#     Monkey throws item to monkey 4.
#   Monkey inspects an item with a worry level of 93.
#     Worry level is set to 100.
#     Monkey gets bored with item. Worry level is divided by 3 to 100.
#     Failed the monkey's check
#     Monkey throws item to monkey 4.
#   Monkey inspects an item with a worry level of 65.
#     Worry level is set to 72.
#     Monkey gets bored with item. Worry level is divided by 3 to 72.
#     Failed the monkey's check
#     Monkey throws item to monkey 4.
#   Monkey inspects an item with a worry level of 80.
#     Worry level is set to 87.
#     Monkey gets bored with item. Worry level is divided by 3 to 87.
#     Failed the monkey's check
#     Monkey throws item to monkey 4.
#   Monkey inspects an item with a worry level of 68.
#     Worry level is set to 75.
#     Monkey gets bored with item. Worry level is divided by 3 to 75.
#     Failed the monkey's check
#     Monkey throws item to monkey 4.
#   Monkey inspects an item with a worry level of 54.
#     Worry level is set to 61.
#     Monkey gets bored with item. Worry level is divided by 3 to 61.
#     Failed the monkey's check
#     Monkey throws item to monkey 4.
#   Monkey inspects an item with a worry level of 71.
#     Worry level is set to 78.
#     Monkey gets bored with item. Worry level is divided by 3 to 78.
#     Failed the monkey's check
#     Monkey throws item to monkey 4.
#   Monkey inspects an item with a worry level of 1089.
#     Worry level is set to 1096.
#     Monkey gets bored with item. Worry level is divided by 3 to 1096.
#     Failed the monkey's check
#     Monkey throws item to monkey 4.
# Monkey 4
#   Monkey inspects an item with a worry level of 97.
#     Worry level is set to 102.
#     Monkey gets bored with item. Worry level is divided by 3 to 102.
#     Failed the monkey's check
#     Monkey throws item to monkey 0.
#   Monkey inspects an item with a worry level of 56.
#     Worry level is set to 61.
#     Monkey gets bored with item. Worry level is divided by 3 to 61.
#     Failed the monkey's check
#     Monkey throws item to monkey 0.
#   Monkey inspects an item with a worry level of 79.
#     Worry level is set to 84.
#     Monkey gets bored with item. Worry level is divided by 3 to 84.
#     Failed the monkey's check
#     Monkey throws item to monkey 0.
#   Monkey inspects an item with a worry level of 65.
#     Worry level is set to 70.
#     Monkey gets bored with item. Worry level is divided by 3 to 70.
#     Passed the monkey's check
#     Monkey throws item to monkey 2.
#   Monkey inspects an item with a worry level of 58.
#     Worry level is set to 63.
#     Monkey gets bored with item. Worry level is divided by 3 to 63.
#     Failed the monkey's check
#     Monkey throws item to monkey 0.
#   Monkey inspects an item with a worry level of 78.
#     Worry level is set to 83.
#     Monkey gets bored with item. Worry level is divided by 3 to 83.
#     Failed the monkey's check
#     Monkey throws item to monkey 0.
#   Monkey inspects an item with a worry level of 65.
#     Worry level is set to 70.
#     Monkey gets bored with item. Worry level is divided by 3 to 70.
#     Passed the monkey's check
#     Monkey throws item to monkey 2.
#   Monkey inspects an item with a worry level of 100.
#     Worry level is set to 105.
#     Monkey gets bored with item. Worry level is divided by 3 to 105.
#     Passed the monkey's check
#     Monkey throws item to monkey 2.
#   Monkey inspects an item with a worry level of 72.
#     Worry level is set to 77.
#     Monkey gets bored with item. Worry level is divided by 3 to 77.
#     Failed the monkey's check
#     Monkey throws item to monkey 0.
#   Monkey inspects an item with a worry level of 87.
#     Worry level is set to 92.
#     Monkey gets bored with item. Worry level is divided by 3 to 92.
#     Failed the monkey's check
#     Monkey throws item to monkey 0.
#   Monkey inspects an item with a worry level of 75.
#     Worry level is set to 80.
#     Monkey gets bored with item. Worry level is divided by 3 to 80.
#     Passed the monkey's check
#     Monkey throws item to monkey 2.
#   Monkey inspects an item with a worry level of 61.
#     Worry level is set to 66.
#     Monkey gets bored with item. Worry level is divided by 3 to 66.
#     Failed the monkey's check
#     Monkey throws item to monkey 0.
#   Monkey inspects an item with a worry level of 78.
#     Worry level is set to 83.
#     Monkey gets bored with item. Worry level is divided by 3 to 83.
#     Failed the monkey's check
#     Monkey throws item to monkey 0.
#   Monkey inspects an item with a worry level of 1096.
#     Worry level is set to 1101.
#     Monkey gets bored with item. Worry level is divided by 3 to 1101.
#     Failed the monkey's check
#     Monkey throws item to monkey 0.
# Monkey 5
#   Monkey inspects an item with a worry level of 77.
#     Worry level is set to 81.
#     Monkey gets bored with item. Worry level is divided by 3 to 81.
#     Failed the monkey's check
#     Monkey throws item to monkey 3.
#   Monkey inspects an item with a worry level of 880.
#     Worry level is set to 884.
#     Monkey gets bored with item. Worry level is divided by 3 to 884.
#     Failed the monkey's check
#     Monkey throws item to monkey 3.
# Monkey 6
#   Monkey inspects an item with a worry level of 99.
#     Worry level is set to 9801.
#     Monkey gets bored with item. Worry level is divided by 3 to 9801.
#     Failed the monkey's check
#     Monkey throws item to monkey 1.
#   Monkey inspects an item with a worry level of 90.
#     Worry level is set to 8100.
#     Monkey gets bored with item. Worry level is divided by 3 to 8100.
#     Failed the monkey's check
#     Monkey throws item to monkey 1.
#   Monkey inspects an item with a worry level of 84.
#     Worry level is set to 7056.
#     Monkey gets bored with item. Worry level is divided by 3 to 7056.
#     Failed the monkey's check
#     Monkey throws item to monkey 1.
#   Monkey inspects an item with a worry level of 50.
#     Worry level is set to 2500.
#     Monkey gets bored with item. Worry level is divided by 3 to 2500.
#     Failed the monkey's check
#     Monkey throws item to monkey 1.
#   Monkey inspects an item with a worry level of 82.
#     Worry level is set to 6724.
#     Monkey gets bored with item. Worry level is divided by 3 to 6724.
#     Failed the monkey's check
#     Monkey throws item to monkey 1.
#   Monkey inspects an item with a worry level of 68.
#     Worry level is set to 4624.
#     Monkey gets bored with item. Worry level is divided by 3 to 4624.
#     Passed the monkey's check
#     Monkey throws item to monkey 7.
#   Monkey inspects an item with a worry level of 82.
#     Worry level is set to 6724.
#     Monkey gets bored with item. Worry level is divided by 3 to 6724.
#     Failed the monkey's check
#     Monkey throws item to monkey 1.
#   Monkey inspects an item with a worry level of 71.
#     Worry level is set to 5041.
#     Monkey gets bored with item. Worry level is divided by 3 to 5041.
#     Failed the monkey's check
#     Monkey throws item to monkey 1.
#   Monkey inspects an item with a worry level of 94.
#     Worry level is set to 8836.
#     Monkey gets bored with item. Worry level is divided by 3 to 8836.
#     Failed the monkey's check
#     Monkey throws item to monkey 1.
#   Monkey inspects an item with a worry level of 100.
#     Worry level is set to 10000.
#     Monkey gets bored with item. Worry level is divided by 3 to 10000.
#     Failed the monkey's check
#     Monkey throws item to monkey 1.
#   Monkey inspects an item with a worry level of 88.
#     Worry level is set to 7744.
#     Monkey gets bored with item. Worry level is divided by 3 to 7744.
#     Failed the monkey's check
#     Monkey throws item to monkey 1.
# Monkey 7
#   Monkey inspects an item with a worry level of 50.
#     Worry level is set to 53.
#     Monkey gets bored with item. Worry level is divided by 3 to 53.
#     Failed the monkey's check
#     Monkey throws item to monkey 1.
#   Monkey inspects an item with a worry level of 66.
#     Worry level is set to 69.
#     Monkey gets bored with item. Worry level is divided by 3 to 69.
#     Failed the monkey's check
#     Monkey throws item to monkey 1.
#   Monkey inspects an item with a worry level of 61.
#     Worry level is set to 64.
#     Monkey gets bored with item. Worry level is divided by 3 to 64.
#     Passed the monkey's check
#     Monkey throws item to monkey 5.
#   Monkey inspects an item with a worry level of 92.
#     Worry level is set to 95.
#     Monkey gets bored with item. Worry level is divided by 3 to 95.
#     Failed the monkey's check
#     Monkey throws item to monkey 1.
#   Monkey inspects an item with a worry level of 64.
#     Worry level is set to 67.
#     Monkey gets bored with item. Worry level is divided by 3 to 67.
#     Failed the monkey's check
#     Monkey throws item to monkey 1.
#   Monkey inspects an item with a worry level of 78.
#     Worry level is set to 81.
#     Monkey gets bored with item. Worry level is divided by 3 to 81.
#     Failed the monkey's check
#     Monkey throws item to monkey 1.
#   Monkey inspects an item with a worry level of 595.
#     Worry level is set to 598.
#     Monkey gets bored with item. Worry level is divided by 3 to 598.
#     Passed the monkey's check
#     Monkey throws item to monkey 5.
#   Monkey inspects an item with a worry level of 539.
#     Worry level is set to 542.
#     Monkey gets bored with item. Worry level is divided by 3 to 542.
#     Passed the monkey's check
#     Monkey throws item to monkey 5.
#   Monkey inspects an item with a worry level of 539.
#     Worry level is set to 542.
#     Monkey gets bored with item. Worry level is divided by 3 to 542.
#     Passed the monkey's check
#     Monkey throws item to monkey 5.
#   Monkey inspects an item with a worry level of 4624.
#     Worry level is set to 4627.
#     Monkey gets bored with item. Worry level is divided by 3 to 4627.
#     Failed the monkey's check
#     Monkey throws item to monkey 1.
# [{'id': 0, 'items': [102, 61, 84, 63, 83, 77, 92, 66, 83, 1101], 'operation': <function parse_monkey.<locals>.operation at 0x7fa659894430>, 'test': {'check': <function parse_monkey.<locals>.<lambda> at 0x7fa659894f70>, 'true_target': 6, 'false_target': 7}, 'inspections': 3}, {'id': 1, 'items': [9801, 8100, 7056, 2500, 6724, 6724, 5041, 8836, 10000, 7744, 53, 69, 95, 67, 81, 4627], 'operation': <function parse_monkey.<locals>.operation at 0x7fa65acd7160>, 'test': {'check': <function parse_monkey.<locals>.<lambda> at 0x7fa65acd7a60>, 'true_target': 3, 'false_target': 5}, 'inspections': 2}, {'id': 2, 'items': [70, 70, 105, 80], 'operation': <function parse_monkey.<locals>.operation at 0x7fa65acd7040>, 'test': {'check': <function parse_monkey.<locals>.<lambda> at 0x7fa65acd79d0>, 'true_target': 0, 'false_target': 6}, 'inspections': 7}, {'id': 3, 'items': [81, 884], 'operation': <function parse_monkey.<locals>.operation at 0x7fa65acd7280>, 'test': {'check': <function parse_monkey.<locals>.<lambda> at 0x7fa65acd71f0>, 'true_target': 2, 'false_target': 4}, 'inspections': 9}, {'id': 4, 'items': [], 'operation': <function parse_monkey.<locals>.operation at 0x7fa65acd73a0>, 'test': {'check': <function parse_monkey.<locals>.<lambda> at 0x7fa65acd7310>, 'true_target': 2, 'false_target': 0}, 'inspections': 14}, {'id': 5, 'items': [64, 598, 542, 542], 'operation': <function parse_monkey.<locals>.operation at 0x7fa65acd74c0>, 'test': {'check': <function parse_monkey.<locals>.<lambda> at 0x7fa65acd7430>, 'true_target': 4, 'false_target': 3}, 'inspections': 2}, {'id': 6, 'items': [], 'operation': <function parse_monkey.<locals>.operation at 0x7fa65acd75e0>, 'test': {'check': <function parse_monkey.<locals>.<lambda> at 0x7fa65acd7550>, 'true_target': 7, 'false_target': 1}, 'inspections': 11}, {'id': 7, 'items': [], 'operation': <function parse_monkey.<locals>.operation at 0x7fa65acd7700>, 'test': {'check': <function parse_monkey.<locals>.<lambda> at 0x7fa65acd7670>, 'true_target': 5, 'false_target': 1}, 'inspections': 10}]
# [{'id': 0,
#   'items': [102, 61, 84, 63, 83, 77, 92, 66, 83, 1101],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 6,
#    'false_target': 7},
#   'inspections': 3},
#  {'id': 1,
#   'items': [9801,
#    8100,
#    7056,
#    2500,
#    6724,
#    6724,
#    5041,
#    8836,
#    10000,
#    7744,
#    53,
#    69,
#    95,
#    67,
#    81,
#    4627],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 3,
#    'false_target': 5},
#   'inspections': 2},
#  {'id': 2,
#   'items': [70, 70, 105, 80],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 0,
#    'false_target': 6},
#   'inspections': 7},
#  {'id': 3,
#   'items': [81, 884],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 2,
#    'false_target': 4},
#   'inspections': 9},
#  {'id': 4,
#   'items': [],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 2,
#    'false_target': 0},
#   'inspections': 14},
#  {'id': 5,
#   'items': [64, 598, 542, 542],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 4,
#    'false_target': 3},
#   'inspections': 2},
#  {'id': 6,
#   'items': [],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 7,
#    'false_target': 1},
#   'inspections': 11},
#  {'id': 7,
#   'items': [],
#   'operation': <function __main__.parse_monkey.<locals>.operation(x)>,
#   'test': {'check': <function __main__.parse_monkey.<locals>.<lambda>(x)>,
#    'true_target': 5,
#    'false_target': 1},
#   'inspections': 10}]

# %%
[monkey['inspections'] for monkey in run_monkeys_n_times(get_monkeys('example.txt'), 1_000)]
# Out:
# Iteration: 0
# Monkey 0 has inspected 2 items.
# Monkey 1 has inspected 4 items.
# Monkey 2 has inspected 3 items.
# Monkey 3 has inspected 6 items.
#
# Iteration: 100
# Monkey 0 has inspected 502 items.
# Monkey 1 has inspected 504 items.
# Monkey 2 has inspected 3 items.
# Monkey 3 has inspected 506 items.
#
# Iteration: 200
# Monkey 0 has inspected 996 items.
# Monkey 1 has inspected 1010 items.
# Monkey 2 has inspected 39 items.
# Monkey 3 has inspected 1023 items.
#
# Iteration: 300
# Monkey 0 has inspected 1497 items.
# Monkey 1 has inspected 1509 items.
# Monkey 2 has inspected 49 items.
# Monkey 3 has inspected 1529 items.
#
# Iteration: 400
# Monkey 0 has inspected 1997 items.
# Monkey 1 has inspected 2009 items.
# Monkey 2 has inspected 49 items.
# Monkey 3 has inspected 2029 items.
#
# Iteration: 500
# Monkey 0 has inspected 2497 items.
# Monkey 1 has inspected 2509 items.
# Monkey 2 has inspected 49 items.
# Monkey 3 has inspected 2529 items.
#
# Iteration: 600
# Monkey 0 has inspected 2997 items.
# Monkey 1 has inspected 3009 items.
# Monkey 2 has inspected 49 items.
# Monkey 3 has inspected 3029 items.
#
# Iteration: 700
# Monkey 0 has inspected 3497 items.
# Monkey 1 has inspected 3509 items.
# Monkey 2 has inspected 49 items.
# Monkey 3 has inspected 3529 items.
#
# Iteration: 800
# Monkey 0 has inspected 3997 items.
# Monkey 1 has inspected 4009 items.
# Monkey 2 has inspected 49 items.
# Monkey 3 has inspected 4029 items.
#
# Iteration: 900
# Monkey 0 has inspected 4497 items.
# Monkey 1 has inspected 4509 items.
# Monkey 2 has inspected 49 items.
# Monkey 3 has inspected 4529 items.
# [4992, 5004, 49, 5024]
